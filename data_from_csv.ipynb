# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !sales_data.csv

# %%
sales = pd.read_csv(
    'sales_data.csv',
    parse_dates=['Date']
)

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.shape
# Out:
# (113036, 18)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales['Day'].describe()
# Out:
# count    113036.000000
# mean         15.665753
# std           8.781567
# min           1.000000
# 25%           8.000000
# 50%          16.000000
# 75%          23.000000
# max          31.000000
# Name: Day, dtype: float64

# %%
sales['Year'].median()
# Out:
# 2014.0

# %%
sales['Year'].mean()
# Out:
# 2014.4017392689054

# %%
sales['Year'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Year'].plot(kind='density', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax =sales['Year'].plot(kind='density', figsize=(14,6))
ax.axvline(sales['Date'].mean(), color='red')
ax.axvline(sales['Date'].median(), color='green')

# %%
ax =sales['Year'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2013-11-26
# 1        2015-11-26
# 2        2014-03-23
# 3        2016-03-23
# 4        2014-05-15
#             ...
# 113031   2016-04-12
# 113032   2014-04-02
# 113033   2016-04-02
# 113034   2014-03-04
# 113035   2016-03-04
# Name: Date, Length: 113036, dtype: datetime64[ns]>

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
ax = sales['Year'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %%
corr = sales.corr()
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns), corr.columns));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\baral\Desktop\automate_with_py\data_from_csv.ipynb Cell 22' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/baral/Desktop/automate_with_py/data_from_csv.ipynb#ch0000021?line=1'>2</a> plt.matshow(corr, cmap='RdBu', fignum=fig.number)
#       <a href='vscode-notebook-cell:/c%3A/Users/baral/Desktop/automate_with_py/data_from_csv.ipynb#ch0000021?line=2'>3</a> plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
# ----> <a href='vscode-notebook-cell:/c%3A/Users/baral/Desktop/automate_with_py/data_from_csv.ipynb#ch0000021?line=3'>4</a> plt.yticks(range(len(corr.columns), corr.columns))
#
# TypeError: 'Index' object cannot be interpreted as an integer

# %%
sales.head()
# Out:
#   Div       Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0 2021-08-13  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0 2021-08-14  12:30  Man United           Leeds     5     1   H     1
# 2  E0 2021-08-14  15:00     Burnley        Brighton     1     2   A     1
# 3  E0 2021-08-14  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0 2021-08-14  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# 1     1.93     2.10     1.79
# ...

# %%
sales.plot(kind='scatter', x='Date', y='Year', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Year'>

# %%
sales.head()
# Out:
#   Div       Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0 2021-08-13  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0 2021-08-14  12:30  Man United           Leeds     5     1   H     1
# 2  E0 2021-08-14  15:00     Burnley        Brighton     1     2   A     1
# 3  E0 2021-08-14  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0 2021-08-14  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# 1     1.93     2.10     1.79
# ...

# %%
ax = sales[['Date', "Year"]].boxplot(by='Date', figsize=(10, 6))

# %%
sales['Calculated_Cost'] = sales['Order_Quantity'] * sales['Unit_Cost']
sales['Calculated_Cost'].head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\baral\Desktop\automate_with_py\data_from_csv.ipynb Cell 27' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/baral/Desktop/automate_with_py/data_from_csv.ipynb#ch0000027?line=0'>1</a> sales['Calculated_Cost'] = sales['Order_Quantity'] * sales['Unit_Cost']
#       <a href='vscode-notebook-cell:/c%3A/Users/baral/Desktop/automate_with_py/data_from_csv.ipynb#ch0000027?line=1'>2</a> sales['Calculated_Cost'].head
#
# NameError: name 'sales' is not defined
